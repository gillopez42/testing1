# %% [markdown]
# Okayyyy so we are rinsing and repeating what we did on our own from 2023 for 2024 for HI!! Let's do it!!

# %%
# Import Libraries
import os
import earthaccess
import numpy as np
import geopandas as gpd
import pandas as pd
import xarray as xr
import rioxarray as rxr
from rioxarray.merge import merge_arrays
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm

# %%
# QC flag codes -- from singleband_raster_hierarchy() in create_frcov_masks.py,
# https://github.com/emit-sds/emit-sds-frcov (not formally published in the User Guide).
# Hierarchical: each pixel gets the FIRST condition below that applies to it.
flag_labels = {
    0: "clear",
    1: "cloud_or_cirrus",
    2: "urban",
    3: "water_or_coastal",
    4: "snow_ice",
}  # -9999 = nodata (outside scene footprint); handled separately via masked=True on load

flag_colors = ["#2ca02c", "#7f7f7f", "#d62728", "#1f77b4", "#f2f2f2"]
cmap = ListedColormap(flag_colors)
norm = BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5, 4.5], cmap.N)

# %%
# Authenticate with NASA Earthdata (reads ~/.netrc, or prompts + persists on first run)
auth = earthaccess.login(persist=True)

# %%
# EMIT L2B Fractional Cover & Uncertainty (60 m, V001) over Maui.
# Currently narrowed to the exact acquisition date (2025-08-17) of the granule from
# https://search.earthdata.nasa.gov/...&g=G3991818701-LPCLOUD -- widen `temporal`
# (e.g. back to a month-long window) to search more broadly.
bbox = (-160.245911, 18.910690, -154.806622, 22.232707)  # (lon_min, lat_min, lon_max, lat_max)(West, South, East, North) in decimal degrees/boundaries
temporal = ("2024-01-31", "2024-12-31")  # (start_date, end_date) in YYYY-MM-DD format

results = earthaccess.search_data(
    concept_id="C3911089796-LPCLOUD",  # EMIT_L2BFRCOV.001 collection (LPCLOUD)
    bounding_box=bbox,
    temporal=temporal,
)

print(f"Found {len(results)} granule(s)")
# Out:
# Found 44 granule(s)
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/results.py:348: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   self["size"] = self.size()

# %% [markdown]
# let's see how many granules we get... OKAYYYY ITS 44 GRANULES YASSSS

# %%
# Print every file (granule ID + all associated data/browse links) found in the search
for granule in results:
    print(granule["meta"]["native-id"])
    for link in granule.data_links():
        print(f"  {link}")
# Out:
# EMIT_L2B_FRCOV_001_20240201T203916_2403214_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVQC_001_20240201T203916_2403214_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVPV_001_20240201T203916_2403214_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVPVUNC_001_20240201T203916_2403214_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVNPV_001_20240201T203916_2403214_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVNPVUNC_001_20240201T203916_2403214_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVBARE_001_20240201T203916_2403214_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240201T203916_2403214_002/EMIT_L2B_FRCOVBAREUNC_001_20240201T203916_2403214_002.tif
# EMIT_L2B_FRCOV_001_20240323T004746_2408301_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVQC_001_20240323T004746_2408301_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVPV_001_20240323T004746_2408301_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVPVUNC_001_20240323T004746_2408301_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVNPV_001_20240323T004746_2408301_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVNPVUNC_001_20240323T004746_2408301_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVBARE_001_20240323T004746_2408301_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240323T004746_2408301_002/EMIT_L2B_FRCOVBAREUNC_001_20240323T004746_2408301_002.tif
# EMIT_L2B_FRCOV_001_20240326T000104_2408516_001
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVQC_001_20240326T000104_2408516_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVPV_001_20240326T000104_2408516_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVPVUNC_001_20240326T000104_2408516_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVNPV_001_20240326T000104_2408516_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVNPVUNC_001_20240326T000104_2408516_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVBARE_001_20240326T000104_2408516_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240326T000104_2408516_001/EMIT_L2B_FRCOVBAREUNC_001_20240326T000104_2408516_001.tif
# EMIT_L2B_FRCOV_001_20240329T222514_2408915_001
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVQC_001_20240329T222514_2408915_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVPV_001_20240329T222514_2408915_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVPVUNC_001_20240329T222514_2408915_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVNPV_001_20240329T222514_2408915_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVNPVUNC_001_20240329T222514_2408915_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVBARE_001_20240329T222514_2408915_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222514_2408915_001/EMIT_L2B_FRCOVBAREUNC_001_20240329T222514_2408915_001.tif
# EMIT_L2B_FRCOV_001_20240329T222526_2408915_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20240329T222526_2408915_002/EMIT_L2B_FRCO
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVQC_001_20241025T205522_2429914_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVPV_001_20241025T205522_2429914_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVPVUNC_001_20241025T205522_2429914_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVNPV_001_20241025T205522_2429914_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVNPVUNC_001_20241025T205522_2429914_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVBARE_001_20241025T205522_2429914_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205522_2429914_002/EMIT_L2B_FRCOVBAREUNC_001_20241025T205522_2429914_002.tif
# EMIT_L2B_FRCOV_001_20241025T205534_2429914_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVQC_001_20241025T205534_2429914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVPV_001_20241025T205534_2429914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVPVUNC_001_20241025T205534_2429914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVNPV_001_20241025T205534_2429914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVNPVUNC_001_20241025T205534_2429914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVBARE_001_20241025T205534_2429914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205534_2429914_003/EMIT_L2B_FRCOVBAREUNC_001_20241025T205534_2429914_003.tif
# EMIT_L2B_FRCOV_001_20241025T205546_2429914_004
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVQC_001_20241025T205546_2429914_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVPV_001_20241025T205546_2429914_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVPVUNC_001_20241025T205546_2429914_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVNPV_001_20241025T205546_2429914_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVNPVUNC_001_20241025T205546_2429914_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVBARE_001_20241025T205546_2429914_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241025T205546_2429914_004/EMIT_L2B_FRCOVBAREUNC_001_20241025T205546_2429914_004.tif
# EMIT_L2B_FRCOV_001_20241127T215417_2433215_005
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVQC_001_20241127T215417_2433215_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVPV_001_20241127T215417_2433215_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVPVUNC_001_20241127T215417_2433215_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVNPV_001_20241127T215417_2433215_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVNPVUNC_001_20241127T215417_2433215_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVBARE_001_20241127T215417_2433215_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20241127T215417_2433215_005/EMIT_L2B_FRCOVBAREUNC_001_20241127T215417_2433215_005.tif

# %% [markdown]
# ## Step 2: Locally download granules of interest
#
# For every granule the search above found, there are 7 GeoTIFFs to download. Load them into one
#  `xarray.Dataset`, and apply the QC band as a mask across the fraction
# (PV/NPV/BARE) and uncertainty bands.

# %%
def download_and_reconcile(granule):
    """Download a granule's 7 GeoTIFFs, load into one aligned Dataset, mask
    fraction + uncertainty bands to QC-clear pixels (qc == 0). Returns (ds, ds_clear).
    QC flag source: create_frcov_masks.py in github.com/emit-sds/emit-sds-frcov."""
    granule_id = granule["meta"]["native-id"]
    out_dir = os.path.join("data", "emit_fcov", granule_id)
    os.makedirs(out_dir, exist_ok=True)
    files = earthaccess.download([granule], local_path=out_dir)

    roles = {}
    for f in files:
        name = os.path.basename(f)
        if "FRCOVQC" in name:
            roles["qc"] = f
        elif "FRCOVPVUNC" in name:
            roles["pv_unc"] = f
        elif "FRCOVNPVUNC" in name:
            roles["npv_unc"] = f
        elif "FRCOVBAREUNC" in name:
            roles["bare_unc"] = f
        elif "FRCOVPV" in name:
            roles["pv"] = f
        elif "FRCOVNPV" in name:
            roles["npv"] = f
        elif "FRCOVBARE" in name:
            roles["bare"] = f
    assert len(roles) == 7, f"Expected 7 bands, matched {len(roles)}: {roles}"

    g_ds = xr.Dataset(
        {role: rxr.open_rasterio(path, masked=True).squeeze("band", drop=True)
         for role, path in roles.items()}
    )

    clear = g_ds["qc"] == 0  # only unflagged pixels are retrieval-valid per the ATBD mask hierarchy
    g_ds_clear = g_ds.copy()
    for v in ["pv", "npv", "bare", "pv_unc", "npv_unc", "bare_unc"]:
        g_ds_clear[v] = g_ds[v].where(clear)

    return g_ds, g_ds_clear

# %%
# Out:
# Processing EMIT_L2B_FRCOV_001_20240201T203916_2403214_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1951363 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240323T004746_2408301_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   26965/1939651 pixels clear (1.4%)
# Processing EMIT_L2B_FRCOV_001_20240326T000104_2408516_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   34923/1992462 pixels clear (1.8%)
# Processing EMIT_L2B_FRCOV_001_20240329T222514_2408915_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   741839/1616322 pixels clear (45.9%)
# Processing EMIT_L2B_FRCOV_001_20240329T222526_2408915_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   1859175/1966129 pixels clear (94.6%)
# Processing EMIT_L2B_FRCOV_001_20240329T222538_2408915_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   66602/2618099 pixels clear (2.5%)
# Processing EMIT_L2B_FRCOV_001_20240402T204844_2409314_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   101800/1934503 pixels clear (5.3%)
# Processing EMIT_L2B_FRCOV_001_20240402T204908_2409314_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   193158/3804360 pixels clear (5.1%)
# Processing EMIT_L2B_FRCOV_001_20240419T001056_2410916_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   11738/1961731 pixels clear (0.6%)
# Processing EMIT_L2B_FRCOV_001_20240419T001108_2410916_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   962340/2685465 pixels clear (35.8%)
# Processing EMIT_L2B_FRCOV_001_20240422T223212_2411315_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   51874/1965902 pixels clear (2.6%)
# Processing EMIT_L2B_FRCOV_001_20240422T223224_2411315_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   247707/1951081 pixels clear (12.7%)
# Processing EMIT_L2B_FRCOV_001_20240422T223236_2411315_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1886332 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240422T223248_2411315_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1928371 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240422T223300_2411315_005 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1922137 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240422T223312_2411315_006 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   99179/1967456 pixels clear (5.0%)
# Processing EMIT_L2B_FRCOV_001_20240426T205237_2411714_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   5716/1866484 pixels clear (0.3%)
# Processing EMIT_L2B_FRCOV_001_20240426T205249_2411714_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   3/1418984 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240426T205301_2411714_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   41975/1656453 pixels clear (2.5%)
# Processing EMIT_L2B_FRCOV_001_20240426T205313_2411714_005 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   68898/1941873 pixels clear (3.5%)
# Processing EMIT_L2B_FRCOV_001_20240426T205325_2411714_006 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   411552/1061044 pixels clear (38.8%)
# Processing EMIT_L2B_FRCOV_001_20240426T205336_2411714_007 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   8179/2836509 pixels clear (0.3%)
# Processing EMIT_L2B_FRCOV_001_20240624T213614_2417614_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   58612/1862365 pixels clear (3.1%)
# Processing EMIT_L2B_FRCOV_001_20240624T213626_2417614_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   11570/2204160 pixels clear (0.5%)
# Processing EMIT_L2B_FRCOV_001_20240702T182611_2418412_007 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   486429/1973155 pixels clear (24.7%)
# Processing EMIT_L2B_FRCOV_001_20240721T012334_2420301_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   66134/1938980 pixels clear (3.4%)
# Processing EMIT_L2B_FRCOV_001_20240724T003444_2420601_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   45394/1727595 pixels clear (2.6%)
# Processing EMIT_L2B_FRCOV_001_20240724T003456_2420601_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   19231/1783827 pixels clear (1.1%)
# Processing EMIT_L2B_FRCOV_001_20240727T225654_2420915_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   545149/1972881 pixels clear (27.6%)
# Processing EMIT_L2B_FRCOV_001_20240727T225706_2420915_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/3370252 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240804T194339_2421713_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   8202/1983412 pixels clear (0.4%)
# Processing EMIT_L2B_FRCOV_001_20240820T230604_2423315_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   14458/1970449 pixels clear (0.7%)
# Processing EMIT_L2B_FRCOV_001_20240820T230616_2423315_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   32855/1962097 pixels clear (1.7%)
# Processing EMIT_L2B_FRCOV_001_20240820T230628_2423315_005 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   1030974/2684492 pixels clear (38.4%)
# Processing EMIT_L2B_FRCOV_001_20240923T235434_2426716_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   1178358/1939722 pixels clear (60.7%)
# Processing EMIT_L2B_FRCOV_001_20240923T235446_2426716_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   900444/1946870 pixels clear (46.3%)
# Processing EMIT_L2B_FRCOV_001_20240923T235458_2426716_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   393/2970407 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240927T221939_2427115_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   25740/1614958 pixels clear (1.6%)
# Processing EMIT_L2B_FRCOV_001_20240927T221951_2427115_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1965406 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20240927T222003_2427115_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   1080532/2220578 pixels clear (48.7%)
# Processing EMIT_L2B_FRCOV_001_20241025T205522_2429914_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1660101 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20241025T205534_2429914_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1653047 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20241025T205546_2429914_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   11894/1936715 pixels clear (0.6%)
# Processing EMIT_L2B_FRCOV_001_20241127T215417_2433215_005 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   873318/1804713 pixels clear (48.4%)
#
# Reconciled 44 granule(s).

# %% [markdown]
# # Mosaic All Scenes
#
# Merge every granule's QC-masked Dataset into one continuous mosaic. Works for any number
# of granules (1..N) — if the search above returns a single scene the "mosaic" is just
# that scene; if it returns several, they all get merged into one.

# %%
mosaic_vars = ["qc", "pv", "npv", "bare", "pv_unc", "npv_unc", "bare_unc"]

ds_mosaic = xr.Dataset({
    v: merge_arrays([g_ds_clear[v] for _, g_ds_clear in granules.values()], nodata=np.nan)
    for v in mosaic_vars
})

print(f"Mosaicked {len(granules)} scene(s) -> shape {ds_mosaic['pv'].shape}")

frac_sum = ds_mosaic["pv"] + ds_mosaic["npv"] + ds_mosaic["bare"]
print(f"Mosaic PV+NPV+BARE (clear pixels) -> mean: {float(frac_sum.mean(skipna=True)):.4f}, "
      f"std: {float(frac_sum.std(skipna=True)):.4f} (should be ~1.0 / ~0)")
# Out:
# Mosaicked 44 scene(s) -> shape (9745, 13135)
# Mosaic PV+NPV+BARE (clear pixels) -> mean: 1.0000, std: 0.0000 (should be ~1.0 / ~0)

# %%
print(ds_mosaic.nbytes / 1e9, "GB")
print(ds_mosaic.dims)
# Out:
# 6.656212948 GB
# FrozenMappingWarningOnValuesAccess({'x': 13135, 'y': 9745})

# %% [markdown]
# going to coarsen it by factors of 30, 20, 10, 5, and 3

# %%
factor = 3  # try 20 if this still crashes, or 5 if you want more detail

def prep(band):
    return ds_mosaic[band].fillna(0).coarsen(x=factor, y=factor, boundary="trim").mean()

rgb_mosaic = xr.concat([prep("bare"), prep("pv"), prep("npv")], dim="band").transpose("y", "x", "band")
rgb_mosaic = rgb_mosaic.compute()

qc_small = ds_mosaic["qc"].coarsen(x=factor, y=factor, boundary="trim").mean().compute()

# %% [markdown]
# Plot at the bottom:

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

im0 = ds_mosaic["qc"].plot.imshow(ax=axes[0], cmap=cmap, norm=norm, add_colorbar=False)
axes[0].set_title(f"Mosaic QC Flags ({len(granules)} scene(s))")
axes[0].set_aspect("equal")
cbar = fig.colorbar(im0, ax=axes[0], ticks=[0, 1, 2, 3, 4])
cbar.ax.set_yticklabels(list(flag_labels.values()))

rgb_mosaic = xr.concat(
    [ds_mosaic["bare"].fillna(0), ds_mosaic["pv"].fillna(0), ds_mosaic["npv"].fillna(0)],
    dim="band",
).transpose("y", "x", "band")

rgb_mosaic.plot.imshow(ax=axes[1], rgb="band")
axes[1].set_title("Mosaic Fractional Cover (R=BARE, G=PV, B=NPV)")
axes[1].set_aspect("equal")

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000000000000002].

# %% [markdown]
# Export Mosaic (Analysis-Ready GeoTIFFs)

# %%
export_dir = os.path.join("data", "processed")
os.makedirs(export_dir, exist_ok=True)

for var in mosaic_vars:
    out_path = os.path.join(export_dir, f"emit_2024fcov_mosaic_{var}.tif")
    da = ds_mosaic[var]
    # qc is integer-dtype -- reuse its native -9999 nodata sentinel (see flag_labels
    # comment above) since NaN isn't representable in an int raster. Everything else
    # (fraction + uncertainty bands) is float, so NaN is fine.
    nodata = -9999 if var == "qc" else np.nan
    # Both attrs and encoding can carry a stale _FillValue (attrs from write_nodata()
    # below, encoding inherited from open_rasterio(masked=True) via merge_arrays) --
    # to_raster()'s CF encoder refuses to reconcile them itself, so clear both first.
    da.attrs.pop("_FillValue", None)
    da.encoding.pop("_FillValue", None)
    if var == "qc":
        da = da.fillna(nodata).astype("int16")
    da.rio.write_nodata(nodata, inplace=True)
    da.rio.to_raster(out_path, compress="LZW")
    print(f"Wrote {out_path}")
# Out:
# Wrote data/processed/emit_2024fcov_mosaic_qc.tif
# Wrote data/processed/emit_2024fcov_mosaic_pv.tif
# Wrote data/processed/emit_2024fcov_mosaic_npv.tif
# Wrote data/processed/emit_2024fcov_mosaic_bare.tif
# Wrote data/processed/emit_2024fcov_mosaic_pv_unc.tif
# Wrote data/processed/emit_2024fcov_mosaic_npv_unc.tif
# Wrote data/processed/emit_2024fcov_mosaic_bare_unc.tif

# %% [markdown]
# Preliminary Stats

# %%
stats_rows = []
for var in ["pv", "npv", "bare"]:
    data = ds_mosaic[var].compute()
    unc = ds_mosaic[f"{var}_unc"].compute()
    stats_rows.append({
        "band": var,
        "mean": float(data.mean(skipna=True)),
        "median": float(data.median(skipna=True)),
        "std": float(data.std(skipna=True)),
        "min": float(data.min(skipna=True)),
        "max": float(data.max(skipna=True)),
        "mean_uncertainty": float(unc.mean(skipna=True)),
    })

stats_df = pd.DataFrame(stats_rows).set_index("band")
print(stats_df.round(4))
# Out:
#         mean  median     std  min  max  mean_uncertainty
# band
# pv    0.1122  0.0000  0.2773  0.0  1.0            0.0672
# npv   0.6168  0.7106  0.2489  0.0  1.0            0.3770
# bare  0.2710  0.2706  0.1348  0.0  1.0            0.3496

# %%
# Dominant cover class per pixel (whichever of PV/NPV/BARE has the highest fraction there)
stacked = xr.concat(
    [ds_mosaic["pv"], ds_mosaic["npv"], ds_mosaic["bare"]], dim="band"
).assign_coords(band=["pv", "npv", "bare"])
dominant = stacked.idxmax(dim="band")

n_valid = int(dominant.notnull().sum())
print(f"\nDominant cover class ({n_valid} clear pixels):")
for label in ["pv", "npv", "bare"]:
    n = int((dominant == label).sum())
    print(f"  {label:5s}: {n:8d}  ({100 * n / n_valid:5.1f}%)")
# Out:
# Dominant cover class (9573912 clear pixels):
#   pv   :  1120690  ( 11.7%)
#   npv  :  7969468  ( 83.2%)
#   bare :   483754  (  5.1%)
