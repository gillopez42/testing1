# %% [markdown]
# Finishing for 2026 now for HI!!! LET'S DO THIS

# %%
# Import Libraries
import os
import earthaccess
import numpy as np
import geopandas as gpd
import pandas as pd
import xarray as xr
import rioxarray as rxr
from rioxarray.merge import merge_arrays
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm

# %%
# QC flag codes -- from singleband_raster_hierarchy() in create_frcov_masks.py,
# https://github.com/emit-sds/emit-sds-frcov (not formally published in the User Guide).
# Hierarchical: each pixel gets the FIRST condition below that applies to it.
flag_labels = {
    0: "clear",
    1: "cloud_or_cirrus",
    2: "urban",
    3: "water_or_coastal",
    4: "snow_ice",
}  # -9999 = nodata (outside scene footprint); handled separately via masked=True on load

flag_colors = ["#2ca02c", "#7f7f7f", "#d62728", "#1f77b4", "#f2f2f2"]
cmap = ListedColormap(flag_colors)
norm = BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5, 4.5], cmap.N)

# %%
# Authenticate with NASA Earthdata (reads ~/.netrc, or prompts + persists on first run)
auth = earthaccess.login(persist=True)

# %%
# EMIT L2B Fractional Cover & Uncertainty (60 m, V001) over Maui.
# Currently narrowed to the exact acquisition date (2025-08-17) of the granule from
# https://search.earthdata.nasa.gov/...&g=G3991818701-LPCLOUD -- widen `temporal`
# (e.g. back to a month-long window) to search more broadly.
bbox = (-160.245911, 18.910690, -154.806622, 22.232707)  # (lon_min, lat_min, lon_max, lat_max) i.e., (West, South, East, North) in decimal degrees/boundaries
temporal = ("2026-01-31", "2026-12-31")  # (start_date, end_date) in YYYY-MM-DD format

results = earthaccess.search_data(
    concept_id="C3911089796-LPCLOUD",  # EMIT_L2BFRCOV.001 collection (LPCLOUD)
    bounding_box=bbox,
    temporal=temporal,
)

print(f"Found {len(results)} granule(s)")
# Out:
# Found 25 granule(s)
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/results.py:348: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   self["size"] = self.size()

# %% [markdown]
# At least up until 7/9/2026, we have 25 granules!!

# %%
# Print every file (granule ID + all associated data/browse links) found in the search
for granule in results:
    print(granule["meta"]["native-id"])
    for link in granule.data_links():
        print(f"  {link}")
# Out:
# EMIT_L2B_FRCOV_001_20260323T000942_2608115_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVQC_001_20260323T000942_2608115_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVPV_001_20260323T000942_2608115_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVPVUNC_001_20260323T000942_2608115_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVNPV_001_20260323T000942_2608115_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVNPVUNC_001_20260323T000942_2608115_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVBARE_001_20260323T000942_2608115_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T000942_2608115_002/EMIT_L2B_FRCOVBAREUNC_001_20260323T000942_2608115_002.tif
# EMIT_L2B_FRCOV_001_20260323T001006_2608115_004
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVQC_001_20260323T001006_2608115_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVPV_001_20260323T001006_2608115_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVPVUNC_001_20260323T001006_2608115_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVNPV_001_20260323T001006_2608115_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVNPVUNC_001_20260323T001006_2608115_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVBARE_001_20260323T001006_2608115_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260323T001006_2608115_004/EMIT_L2B_FRCOVBAREUNC_001_20260323T001006_2608115_004.tif
# EMIT_L2B_FRCOV_001_20260326T223834_2608515_001
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVQC_001_20260326T223834_2608515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVPV_001_20260326T223834_2608515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVPVUNC_001_20260326T223834_2608515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVNPV_001_20260326T223834_2608515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVNPVUNC_001_20260326T223834_2608515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVBARE_001_20260326T223834_2608515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223834_2608515_001/EMIT_L2B_FRCOVBAREUNC_001_20260326T223834_2608515_001.tif
# EMIT_L2B_FRCOV_001_20260326T223846_2608515_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVQC_001_20260326T223846_2608515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVPV_001_20260326T223846_2608515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVPVUNC_001_20260326T223846_2608515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVNPV_001_20260326T223846_2608515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVNPVUNC_001_20260326T223846_2608515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVBARE_001_20260326T223846_2608515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223846_2608515_002/EMIT_L2B_FRCOVBAREUNC_001_20260326T223846_2608515_002.tif
# EMIT_L2B_FRCOV_001_20260326T223858_2608515_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVQC_001_20260326T223858_2608515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVPV_001_20260326T223858_2608515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVPVUNC_001_20260326T223858_2608515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVNPV_001_20260326T223858_2608515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVNPVUNC_001_20260326T223858_2608515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVBARE_001_20260326T223858_2608515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260326T223858_2608515_003/EMIT_L2B_FRCOVBAREUNC_001_20260326T223858_2608515_003.tif
# EMIT_L2B_FRCOV_001_20260331T202008_2609013_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVQC_001_20260331T202008_2609013_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVPV_001_20260331T202008_2609013_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVPVUNC_001_20260331T202008_2609013_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVNPV_001_20260331T202008_2609013_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVNPVUNC_001_20260331T202008_2609013_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVBARE_001_20260331T202008_2609013_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260331T202008_2609013_003/EMIT_L2B_FRCOVBAREUNC_001_20260331T202008_2609013_003.tif
# EMIT_L2B_FRCOV_001_20260420T222900_2611014_006
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVQC_001_20260420T222900_2611014_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVPV_001_20260420T222900_2611014_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVPVUNC_001_20260420T222900_2611014_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVNPV_001_20260420T222900_2611014_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVNPVUNC_001_20260420T222900_2611014_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVBARE_001_20260420T222900_2611014_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260420T222900_2611014_006/EMIT_L2B_FRCOVBAREUNC_001_20260420T222900_2611014_006.tif
# EMIT_L2B_FRCOV_001_20260524T232504_2614415_001
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVQC_001_20260524T232504_2614415_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVPV_001_20260524T232504_2614415_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVPVUNC_001_20260524T232504_2614415_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVNPV_001_20260524T232504_2614415_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVNPVUNC_001_20260524T232504_2614415_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVBARE_001_20260524T232504_2614415_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232504_2614415_001/EMIT_L2B_FRCOVBAREUNC_001_20260524T232504_2614415_001.tif
# EMIT_L2B_FRCOV_001_20260524T232516_2614415_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVQC_001_20260524T232516_2614415_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVPV_001_20260524T232516_2614415_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVPVUNC_001_20260524T232516_2614415_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVNPV_001_20260524T232516_2614415_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVNPVUNC_001_20260524T232516_2614415_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVBARE_001_20260524T232516_2614415_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260524T232516_2614415_002/EMIT_L2B_FRCOVBAREUNC_001_20260524T232516_2614415_002.tif
# EMIT_L2B_FRCOV_001_20260525T223724_2614515_001
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVQC_001_20260525T223724_2614515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVPV_001_20260525T223724_2614515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVPVUNC_001_20260525T223724_2614515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVNPV_001_20260525T223724_2614515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVNPVUNC_001_20260525T223724_2614515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVBARE_001_20260525T223724_2614515_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223724_2614515_001/EMIT_L2B_FRCOVBAREUNC_001_20260525T223724_2614515_001.tif
# EMIT_L2B_FRCOV_001_20260525T223736_2614515_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVQC_001_20260525T223736_2614515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVPV_001_20260525T223736_2614515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVPVUNC_001_20260525T223736_2614515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVNPV_001_20260525T223736_2614515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVNPVUNC_001_20260525T223736_2614515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVBARE_001_20260525T223736_2614515_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223736_2614515_002/EMIT_L2B_FRCOVBAREUNC_001_20260525T223736_2614515_002.tif
# EMIT_L2B_FRCOV_001_20260525T223748_2614515_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVQC_001_20260525T223748_2614515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVPV_001_20260525T223748_2614515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVPVUNC_001_20260525T223748_2614515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVNPV_001_20260525T223748_2614515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVNPVUNC_001_20260525T223748_2614515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVBARE_001_20260525T223748_2614515_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260525T223748_2614515_003/EMIT_L2B_FRCOVBAREUNC_001_20260525T223748_2614515_003.tif
# EMIT_L2B_FRCOV_001_20260528T215024_2614814_001
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVQC_001_20260528T215024_2614814_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVPV_001_20260528T215024_2614814_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVPVUNC_001_20260528T215024_2614814_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVNPV_001_20260528T215024_2614814_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVNPVUNC_001_20260528T215024_2614814_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVBARE_001_20260528T215024_2614814_001.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215024_2614814_001/EMIT_L2B_FRCOVBAREUNC_001_20260528T215024_2614814_001.tif
# EMIT_L2B_FRCOV_001_20260528T215036_2614814_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVQC_001_20260528T215036_2614814_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVPV_001_20260528T215036_2614814_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVPVUNC_001_20260528T215036_2614814_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVNPV_001_20260528T215036_2614814_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVNPVUNC_001_20260528T215036_2614814_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVBARE_001_20260528T215036_2614814_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215036_2614814_002/EMIT_L2B_FRCOVBAREUNC_001_20260528T215036_2614814_002.tif
# EMIT_L2B_FRCOV_001_20260528T215048_2614814_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVQC_001_20260528T215048_2614814_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVPV_001_20260528T215048_2614814_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVPVUNC_001_20260528T215048_2614814_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVNPV_001_20260528T215048_2614814_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVNPVUNC_001_20260528T215048_2614814_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVBARE_001_20260528T215048_2614814_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260528T215048_2614814_003/EMIT_L2B_FRCOVBAREUNC_001_20260528T215048_2614814_003.tif
# EMIT_L2B_FRCOV_001_20260529T210308_2614914_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVQC_001_20260529T210308_2614914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVPV_001_20260529T210308_2614914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVPVUNC_001_20260529T210308_2614914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVNPV_001_20260529T210308_2614914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVNPVUNC_001_20260529T210308_2614914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVBARE_001_20260529T210308_2614914_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260529T210308_2614914_003/EMIT_L2B_FRCOVBAREUNC_001_20260529T210308_2614914_003.tif
# EMIT_L2B_FRCOV_001_20260602T192749_2615313_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVQC_001_20260602T192749_2615313_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVPV_001_20260602T192749_2615313_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVPVUNC_001_20260602T192749_2615313_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVNPV_001_20260602T192749_2615313_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVNPVUNC_001_20260602T192749_2615313_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVBARE_001_20260602T192749_2615313_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260602T192749_2615313_002/EMIT_L2B_FRCOVBAREUNC_001_20260602T192749_2615313_002.tif
# EMIT_L2B_FRCOV_001_20260615T003337_2616516_005
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVQC_001_20260615T003337_2616516_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVPV_001_20260615T003337_2616516_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVPVUNC_001_20260615T003337_2616516_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVNPV_001_20260615T003337_2616516_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVNPVUNC_001_20260615T003337_2616516_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVBARE_001_20260615T003337_2616516_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003337_2616516_005/EMIT_L2B_FRCOVBAREUNC_001_20260615T003337_2616516_005.tif
# EMIT_L2B_FRCOV_001_20260615T003349_2616516_006
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVQC_001_20260615T003349_2616516_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVPV_001_20260615T003349_2616516_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVPVUNC_001_20260615T003349_2616516_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVNPV_001_20260615T003349_2616516_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVNPVUNC_001_20260615T003349_2616516_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVBARE_001_20260615T003349_2616516_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260615T003349_2616516_006/EMIT_L2B_FRCOVBAREUNC_001_20260615T003349_2616516_006.tif
# EMIT_L2B_FRCOV_001_20260618T225937_2616915_002
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVQC_001_20260618T225937_2616915_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVPV_001_20260618T225937_2616915_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVPVUNC_001_20260618T225937_2616915_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVNPV_001_20260618T225937_2616915_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVNPVUNC_001_20260618T225937_2616915_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVBARE_001_20260618T225937_2616915_002.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225937_2616915_002/EMIT_L2B_FRCOVBAREUNC_001_20260618T225937_2616915_002.tif
# EMIT_L2B_FRCOV_001_20260618T225949_2616915_003
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVQC_001_20260618T225949_2616915_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVPV_001_20260618T225949_2616915_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVPVUNC_001_20260618T225949_2616915_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVNPV_001_20260618T225949_2616915_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVNPVUNC_001_20260618T225949_2616915_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVBARE_001_20260618T225949_2616915_003.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T225949_2616915_003/EMIT_L2B_FRCOVBAREUNC_001_20260618T225949_2616915_003.tif
# EMIT_L2B_FRCOV_001_20260618T230001_2616915_004
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVQC_001_20260618T230001_2616915_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVPV_001_20260618T230001_2616915_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVPVUNC_001_20260618T230001_2616915_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVNPV_001_20260618T230001_2616915_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVNPVUNC_001_20260618T230001_2616915_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVBARE_001_20260618T230001_2616915_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260618T230001_2616915_004/EMIT_L2B_FRCOVBAREUNC_001_20260618T230001_2616915_004.tif
# EMIT_L2B_FRCOV_001_20260626T195111_2617713_004
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVQC_001_20260626T195111_2617713_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVPV_001_20260626T195111_2617713_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVPVUNC_001_20260626T195111_2617713_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVNPV_001_20260626T195111_2617713_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVNPVUNC_001_20260626T195111_2617713_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVBARE_001_20260626T195111_2617713_004.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195111_2617713_004/EMIT_L2B_FRCOVBAREUNC_001_20260626T195111_2617713_004.tif
# EMIT_L2B_FRCOV_001_20260626T195123_2617713_005
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVQC_001_20260626T195123_2617713_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVPV_001_20260626T195123_2617713_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVPVUNC_001_20260626T195123_2617713_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVNPV_001_20260626T195123_2617713_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVNPVUNC_001_20260626T195123_2617713_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVBARE_001_20260626T195123_2617713_005.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195123_2617713_005/EMIT_L2B_FRCOVBAREUNC_001_20260626T195123_2617713_005.tif
# EMIT_L2B_FRCOV_001_20260626T195134_2617713_006
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVQC_001_20260626T195134_2617713_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVPV_001_20260626T195134_2617713_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVPVUNC_001_20260626T195134_2617713_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVNPV_001_20260626T195134_2617713_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVNPVUNC_001_20260626T195134_2617713_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVBARE_001_20260626T195134_2617713_006.tif
#   https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/EMITL2BFRCOV.001/EMIT_L2B_FRCOV_001_20260626T195134_2617713_006/EMIT_L2B_FRCOVBAREUNC_001_20260626T195134_2617713_006.tif

# %% [markdown]
# ## Step 2: Locally download granules of interest
#
# For every granule the search above found, there are 7 GeoTIFFs to download. Load them into one
#  `xarray.Dataset`, and apply the QC band as a mask across the fraction
# (PV/NPV/BARE) and uncertainty bands.

# %%
def download_and_reconcile(granule):
    """Download a granule's 7 GeoTIFFs, load into one aligned Dataset, mask
    fraction + uncertainty bands to QC-clear pixels (qc == 0). Returns (ds, ds_clear).
    QC flag source: create_frcov_masks.py in github.com/emit-sds/emit-sds-frcov."""
    granule_id = granule["meta"]["native-id"]
    out_dir = os.path.join("data", "emit_fcov", granule_id)
    os.makedirs(out_dir, exist_ok=True)
    files = earthaccess.download([granule], local_path=out_dir)

    roles = {}
    for f in files:
        name = os.path.basename(f)
        if "FRCOVQC" in name:
            roles["qc"] = f
        elif "FRCOVPVUNC" in name:
            roles["pv_unc"] = f
        elif "FRCOVNPVUNC" in name:
            roles["npv_unc"] = f
        elif "FRCOVBAREUNC" in name:
            roles["bare_unc"] = f
        elif "FRCOVPV" in name:
            roles["pv"] = f
        elif "FRCOVNPV" in name:
            roles["npv"] = f
        elif "FRCOVBARE" in name:
            roles["bare"] = f
    assert len(roles) == 7, f"Expected 7 bands, matched {len(roles)}: {roles}"

    g_ds = xr.Dataset(
        {role: rxr.open_rasterio(path, masked=True).squeeze("band", drop=True)
         for role, path in roles.items()}
    )

    clear = g_ds["qc"] == 0  # only unflagged pixels are retrieval-valid per the ATBD mask hierarchy
    g_ds_clear = g_ds.copy()
    for v in ["pv", "npv", "bare", "pv_unc", "npv_unc", "bare_unc"]:
        g_ds_clear[v] = g_ds[v].where(clear)

    return g_ds, g_ds_clear

# %%
# Process every granule the search found (not just one hardcoded scene) so this
# notebook still works if you change the bbox/temporal window above.
granules = {}
for g in results:
    gid = g["meta"]["native-id"]
    print(f"Processing {gid} ...")
    g_ds, g_ds_clear = download_and_reconcile(g)
    granules[gid] = (g_ds, g_ds_clear)

    total = int(g_ds["qc"].notnull().sum())
    n_clear = int((g_ds["qc"] == 0).sum())
    print(f"  {n_clear}/{total} pixels clear ({100 * n_clear / total:.1f}%)")

print(f"\nReconciled {len(granules)} granule(s).")
# Out:
# Processing EMIT_L2B_FRCOV_001_20260323T000942_2608115_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   803711/2005863 pixels clear (40.1%)
# Processing EMIT_L2B_FRCOV_001_20260323T001006_2608115_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   11430/3085332 pixels clear (0.4%)
# Processing EMIT_L2B_FRCOV_001_20260326T223834_2608515_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   1771625/2002568 pixels clear (88.5%)
# Processing EMIT_L2B_FRCOV_001_20260326T223846_2608515_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/2010538 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260326T223858_2608515_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/2271538 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260331T202008_2609013_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   598965/1976843 pixels clear (30.3%)
# Processing EMIT_L2B_FRCOV_001_20260420T222900_2611014_006 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   254/2442391 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260524T232504_2614415_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   23592/1976018 pixels clear (1.2%)
# Processing EMIT_L2B_FRCOV_001_20260524T232516_2614415_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   8/1983875 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260525T223724_2614515_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   863983/1942983 pixels clear (44.5%)
# Processing EMIT_L2B_FRCOV_001_20260525T223736_2614515_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   174494/1900353 pixels clear (9.2%)
# Processing EMIT_L2B_FRCOV_001_20260525T223748_2614515_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   45022/3721898 pixels clear (1.2%)
# Processing EMIT_L2B_FRCOV_001_20260528T215024_2614814_001 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1972604 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260528T215036_2614814_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   37096/1983349 pixels clear (1.9%)
# Processing EMIT_L2B_FRCOV_001_20260528T215048_2614814_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   24025/3882274 pixels clear (0.6%)
# Processing EMIT_L2B_FRCOV_001_20260529T210308_2614914_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   409108/3822098 pixels clear (10.7%)
# Processing EMIT_L2B_FRCOV_001_20260602T192749_2615313_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1950403 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260615T003337_2616516_005 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1973917 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260615T003349_2616516_006 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   119686/3335890 pixels clear (3.6%)
# Processing EMIT_L2B_FRCOV_001_20260618T225937_2616915_002 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1982005 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260618T225949_2616915_003 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   46309/1973550 pixels clear (2.3%)
# Processing EMIT_L2B_FRCOV_001_20260618T230001_2616915_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1818255 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260626T195111_2617713_004 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/1974906 pixels clear (0.0%)
# Processing EMIT_L2B_FRCOV_001_20260626T195123_2617713_005 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   73460/1966508 pixels clear (3.7%)
# Processing EMIT_L2B_FRCOV_001_20260626T195134_2617713_006 ...
# /Users/gillopez/miniforge3/envs/lpdaac_vitals/lib/python3.12/site-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# QUEUEING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/7 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/7 [00:00<?, ?it/s]
#   0/2398858 pixels clear (0.0%)
#
# Reconciled 25 granule(s).

# %% [markdown]
# # Mosaic All Scenes
#
# Merge every granule's QC-masked Dataset into one continuous mosaic. Works for any number
# of granules (1..N) — if the search above returns a single scene the "mosaic" is just
# that scene; if it returns several, they all get merged into one.

# %%
mosaic_vars = ["qc", "pv", "npv", "bare", "pv_unc", "npv_unc", "bare_unc"]

ds_mosaic = xr.Dataset({
    v: merge_arrays([g_ds_clear[v] for _, g_ds_clear in granules.values()], nodata=np.nan)
    for v in mosaic_vars
})

print(f"Mosaicked {len(granules)} scene(s) -> shape {ds_mosaic['pv'].shape}")

frac_sum = ds_mosaic["pv"] + ds_mosaic["npv"] + ds_mosaic["bare"]
print(f"Mosaic PV+NPV+BARE (clear pixels) -> mean: {float(frac_sum.mean(skipna=True)):.4f}, "
      f"std: {float(frac_sum.std(skipna=True)):.4f} (should be ~1.0 / ~0)")
# Out:
# Mosaicked 25 scene(s) -> shape (9182, 12197)
# Mosaic PV+NPV+BARE (clear pixels) -> mean: 1.0000, std: 0.0000 (should be ~1.0 / ~0)

# %%
print(ds_mosaic.nbytes / 1e9, "GB")
print(ds_mosaic.dims)
# Out:
# 5.823799448 GB
# FrozenMappingWarningOnValuesAccess({'x': 12197, 'y': 9182})

# %%
factor = 3  # try 20 if this still crashes, or 5 if you want more detail

def prep(band):
    return ds_mosaic[band].fillna(0).coarsen(x=factor, y=factor, boundary="trim").mean()

rgb_mosaic = xr.concat([prep("bare"), prep("pv"), prep("npv")], dim="band").transpose("y", "x", "band")
rgb_mosaic = rgb_mosaic.compute()

qc_small = ds_mosaic["qc"].coarsen(x=factor, y=factor, boundary="trim").mean().compute()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

im0 = ds_mosaic["qc"].plot.imshow(ax=axes[0], cmap=cmap, norm=norm, add_colorbar=False)
axes[0].set_title(f"Mosaic QC Flags ({len(granules)} scene(s))")
axes[0].set_aspect("equal")
cbar = fig.colorbar(im0, ax=axes[0], ticks=[0, 1, 2, 3, 4])
cbar.ax.set_yticklabels(list(flag_labels.values()))

rgb_mosaic = xr.concat(
    [ds_mosaic["bare"].fillna(0), ds_mosaic["pv"].fillna(0), ds_mosaic["npv"].fillna(0)],
    dim="band",
).transpose("y", "x", "band")

rgb_mosaic.plot.imshow(ax=axes[1], rgb="band")
axes[1].set_title("Mosaic Fractional Cover (R=BARE, G=PV, B=NPV)")
axes[1].set_aspect("equal")

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000000000000002].

# %% [markdown]
#  Export Mosaic (Analysis-Ready GeoTIFFs)

# %%
export_dir = os.path.join("data", "processed")
os.makedirs(export_dir, exist_ok=True)

for var in mosaic_vars:
    out_path = os.path.join(export_dir, f"emit_2025fcov_mosaic_{var}.tif")
    da = ds_mosaic[var]
    # qc is integer-dtype -- reuse its native -9999 nodata sentinel (see flag_labels
    # comment above) since NaN isn't representable in an int raster. Everything else
    # (fraction + uncertainty bands) is float, so NaN is fine.
    nodata = -9999 if var == "qc" else np.nan
    # Both attrs and encoding can carry a stale _FillValue (attrs from write_nodata()
    # below, encoding inherited from open_rasterio(masked=True) via merge_arrays) --
    # to_raster()'s CF encoder refuses to reconcile them itself, so clear both first.
    da.attrs.pop("_FillValue", None)
    da.encoding.pop("_FillValue", None)
    if var == "qc":
        da = da.fillna(nodata).astype("int16")
    da.rio.write_nodata(nodata, inplace=True)
    da.rio.to_raster(out_path, compress="LZW")
    print(f"Wrote {out_path}")
# Out:
# Wrote data/processed/emit_2025fcov_mosaic_qc.tif
# Wrote data/processed/emit_2025fcov_mosaic_pv.tif
# Wrote data/processed/emit_2025fcov_mosaic_npv.tif
# Wrote data/processed/emit_2025fcov_mosaic_bare.tif
# Wrote data/processed/emit_2025fcov_mosaic_pv_unc.tif
# Wrote data/processed/emit_2025fcov_mosaic_npv_unc.tif
# Wrote data/processed/emit_2025fcov_mosaic_bare_unc.tif

# %% [markdown]
# Preliminary Stats

# %%
stats_rows = []
for var in ["pv", "npv", "bare"]:
    data = ds_mosaic[var].compute()
    unc = ds_mosaic[f"{var}_unc"].compute()
    stats_rows.append({
        "band": var,
        "mean": float(data.mean(skipna=True)),
        "median": float(data.median(skipna=True)),
        "std": float(data.std(skipna=True)),
        "min": float(data.min(skipna=True)),
        "max": float(data.max(skipna=True)),
        "mean_uncertainty": float(unc.mean(skipna=True)),
    })

stats_df = pd.DataFrame(stats_rows).set_index("band")
print(stats_df.round(4))
# Out:
#         mean  median     std  min  max  mean_uncertainty
# band
# pv    0.1872  0.0000  0.3551  0.0  1.0            0.0010
# npv   0.7547  0.9396  0.3571  0.0  1.0            0.0080
# bare  0.0580  0.0286  0.0814  0.0  1.0            0.0081

# %%
# Dominant cover class per pixel (whichever of PV/NPV/BARE has the highest fraction there)
stacked = xr.concat(
    [ds_mosaic["pv"], ds_mosaic["npv"], ds_mosaic["bare"]], dim="band"
).assign_coords(band=["pv", "npv", "bare"])
dominant = stacked.idxmax(dim="band")

n_valid = int(dominant.notnull().sum())
print(f"\nDominant cover class ({n_valid} clear pixels):")
for label in ["pv", "npv", "bare"]:
    n = int((dominant == label).sum())
    print(f"  {label:5s}: {n:8d}  ({100 * n / n_valid:5.1f}%)")
# Out:
# Dominant cover class (4467519 clear pixels):
#   pv   :   856962  ( 19.2%)
#   npv  :  3588745  ( 80.3%)
#   bare :    21812  (  0.5%)
